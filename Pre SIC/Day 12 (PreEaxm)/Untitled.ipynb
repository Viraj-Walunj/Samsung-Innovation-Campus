# %%
terrestrial_planet = {
    'mercury': {
        'mean_radius': 2439.7, 'mass': 3.3022E+23, 'orbital_period': 87.969
    },
    'Venus': {
        'mean_radius': 6051.8, 'mass': 4.8676E+24, 'orbital_period': 224.70069,
    },
    'Earth': {
        'mean_radius': 6371.0, 'mass': 5.97219E+24, 'orbital_period': 365.25641,
    },
    'Mars':{
        'mean_radius':3389.5, 'mass': 6.4185E+23, 'orbital_period': 686.9600,
    }
}
print(terrestrial_planet['Venus']['mean_radius'])
# Out:
# 6051.8

# %%
x = {'a':0, 'b':0, 'c':0, 'd':0}
y = x

# %%
x is y
# Out:
# True

# %%
y is x
# Out:
# True

# %%
x = {'a': {'python':'2.7'}, 'b':{'python': '3.6'}}
import copy
y = copy.deepcopy(x)
y['a']['python'] 
x
# Out:
# {'a': {'python': '2.7'}, 'b': {'python': '3.6'}}

# %%
y
# Out:
# {'a': {'python': '2.7'}, 'b': {'python': '3.6'}}

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 11, 14, 15, 49, 57, 575433)

# %%
today = datetime.datetime.now()
print(today)
# Out:
# 2025-11-14 15:52:01.657612

# %%
today
# Out:
# datetime.datetime(2025, 11, 14, 15, 52, 1, 657612)

# %%
today.year
# Out:
# 2025

# %%
today.month
# Out:
# 11

# %%
today.day
# Out:
# 14

# %%
print(dir(datetime))
# Out:
# ['MAXYEAR', 'MINYEAR', 'UTC', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'date', 'datetime', 'datetime_CAPI', 'time', 'timedelta', 'timezone', 'tzinfo']

# %%
start_time = datetime.datetime.now()
start_time.replace(month = 12, day = 25)
# Out:
# datetime.datetime(2025, 12, 25, 15, 56, 47, 430130)

# %%
import datetime as dt
start_time = dt.datetime.now()
start_time.replace(month = 12, day = 25)
# Out:
# datetime.datetime(2025, 12, 25, 15, 58, 44, 964954)

# %%
from datetime import *
today = date.today()
today
# Out:
# datetime.date(2025, 11, 14)

# %%
import time
seconds = time.time()
print('Time after epoxy =', seconds)
# Out:
# Time after epoxy = 1763116546.568496

# %%
import time
unix_timestamp = time.time()
local_time = time.localtime(unix_timestamp)
local_time
# Out:
# time.struct_time(tm_year=2025, tm_mon=11, tm_mday=14, tm_hour=16, tm_min=9, tm_sec=54, tm_wday=4, tm_yday=318, tm_isdst=0)

# %%
import time 
unix_timestamp = time.time()
local_time = time.localtime(unix_timestamp)
print(time.strftime('%Y-%m-%d %H:%M:%S', local_time))
# Out:
# 2025-11-14 16:14:00

# %%
import math
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fma', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
import math as m
m.pow(3,3)
# Out:
# 27.0

# %%
m.fabs(-99)
# Out:
# 99.0

# %%
m.ceil(2.1)
# Out:
# 3

# %%
m.ceil(-2.1)
# Out:
# -2

# %%
m.floor(2.1)
# Out:
# 2

# %%
m.log(2.71828)
# Out:
# 0.999999327347282

# %%
m.log(100,10)
# Out:
# 2.0

# %%
numbers = {1,2,3}
numbers.add(4)
numbers
# Out:
# {1, 2, 3, 4}

# %%
numbers.remove (4)
numbers
# Out:
# {1, 2, 3}

# %%
set([1,2,3,1,2])
# Out:
# {1, 2, 3}

# %%
set ("abcefa")
# Out:
# {'a', 'b', 'c', 'e', 'f'}

# %%
numbers = set()
numbers
# Out:
# set()

# %%
numbers
# Out:
# set()

# %%
s1 = {1,2,3,4,5,6}
s2 = {4,5,6,7,8,9}
s1 | s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s1 & s2
# Out:
# {4, 5, 6}

# %%
s1 - s2
# Out:
# {1, 2, 3}

# %%
s1 ^ s2
# Out:
# {1, 2, 3, 7, 8, 9}

# %%
numbers = {2,1,3}
for x in numbers:
    print(x, end=" ")
# Out:
# 1 2 3
