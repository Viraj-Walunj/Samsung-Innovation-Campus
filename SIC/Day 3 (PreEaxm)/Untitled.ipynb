# %%
a='This is my first batch'
print(a)
print(type(a))
# Out:
# This is my first batch
# <class 'str'>

# %%
a=100
b=200
if  a<b:
    print('b is greater than a')
else:
    print('a is greater than b')
# Out:
# b is greater than a

# %%
a=int("50")
b=int("50")+20
c=float("10.5")
print(a)
print(b)
print(c)
# Out:
# 50
# 70
# 10.5

# %%
a=2**10
b=9%5
print(a)
print(b)
# Out:
# 1024
# 4

# %%
a=int(input('enter the no'))
b=int(input('enter the second no'))
c=a+b
print(c)
# Out:
# enter the no 10
# enter the second no 20
# 30

# %%
s='welcome'
s.upper()
# Out:
# 'WELCOME'

# %%
s='welcome'
s.capitalize()
# Out:
# 'Welcome'

# %%
s='welcome'

# %%
s='Welcome'
s.lower()
# Out:
# 'welcome'

# %%
s='welcome'
s.startswith("you are")
# Out:
# False

# %%
s='welcome'
s.endswith("me")
# Out:
# True

# %%
a='i am batman'
print(len(a))
# Out:
# 11

# %%
s='beautiful'
print(s.find('i'))
# Out:
# 5

# %%
a='good'
a[0]
# Out:
# 'g'

# %%
a='good'
a[-2]
# Out:
# 'o'

# %%
str='pimprichinchwaduniversity'
print(str[1:3])
# Out:
# im

# %%
str='pimprichinchwaduniversity'
print(str[-10:-3])
# Out:
# univers

# %%
str='pimprichinchwaduniversity'
print(str[::])
# Out:
# pimprichinchwaduniversity

# %%
str='pimprichinchwaduniversity'
print(str[::-1])
# Out:
# ytisrevinudawhcnihcirpmip

# %%
str='pimprichinchwaduniversity'
str[:]
# Out:
# 'pimprichinchwaduniversity'

# %%
a='hello my name is viraj'
a[0:5:2]
# Out:
# 'hlo'

# %%
"hello"[0]
# Out:
# 'h'

# %%
'hello'[0]
# Out:
# 'h'

# %%
radius=4.0
print('Radius of circle',radius)
print('Area of circle',3.14*radius*radius)
print('Circumference of circle',2.0*3.14*radius)
# Out:
# Radius of circle 4.0
# Area of circle 50.24
# Circumference of circle 25.12

# %%
a='hello'
b='world'
print(a+b)
# Out:
# helloworld

# %%
a='hello'
b='world'
print(a,end=' '+b)
# Out:
# hello world

# %%
s1=20
s1+=10
# b-=10
# c*=10
# d/=10
# e=10//5
print(s1)
# print(b)
# print(c)
# print(d)
# print(e)
# Out:
# 30

# %%
weight=float(input("enter the weight"))
height=float(input("enter the height"))
bmi=(weight/(height**2))
print(bmi0\
# Out:
# enter the weight 40
# enter the height 5.9
# 1.1490950876185004
