# %%
li=[1,2,3,4,5,6]
print(li)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a=20
b=10
if a>b:
    print('a is greater than b')
else:
    print('b is greater than a')
# Out:
# a is greater than b

# %%
a=50
b=40
if a>b:
    print('a is greater than b')
elif a<b:
    print('b is greater than a')
else:
    print('Both are equal')
# Out:
# a is greater than b
