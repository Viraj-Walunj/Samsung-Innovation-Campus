# %%
person1 =['David Doe', 20,1,180.0,100.0]
person2 =['Aditya Patole',25,1,170.0,70.0]
person3 =['Utkarsh Sawant',22,0,169.0,60.0]
person4 =['Peter Kelly',40,1,150.0,50.0]

person_list = person1 + person2 + person3 + person4 
\
n_persons = int (len(person_list) / 5)
age_sum = 0.0
for age in person_list[1::5]:
    age_sum += age
average_age = float(age_sum) / n_persons
print('the average age is', str(average_age))
# Out:
# the average age is 26.75

# %%
D ={'Name':'Viraj','age': '34', 'Div':'A'}
print(D)
# Out:
# {'Name': 'Viraj', 'age': '34', 'Div': 'A'}

# %%
fruits = ['banana', 'apple', 'orange', 'kiwi']
print(fruits)
mixed_list = [100,200,'apple',400]
print(mixed_list)
# Out:
# ['banana', 'apple', 'orange', 'kiwi']
# [100, 200, 'apple', 400]

# %%
list4 = list(range(1,10))
list4
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
n_list=[11,22,33,44,55,66]
print(n_list)
print(len(n_list))
# Out:
# [11, 22, 33, 44, 55, 66]
# 6

# %%
person1 =['David Doe', 20,1,180.0,100.0]
person2 =['Aditya Patole',25,1,170.0,70.0]

person_list = person1 + person2
print(person_list)
# Out:
# ['David Doe', 20, 1, 180.0, 100.0, 'Aditya Patole', 25, 1, 170.0, 70.0]

# %%
a_list =['a','b','c','d','e']
a_list.append('f')
a_list
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
a_list =[10,20,30,40]
a_list.append(50)
a_list
# Out:
# [10, 20, 30, 40, 50]

# %%
list1 =['a','b','c']
list2 =[1,2,3]
list1.extend(list2)
list1
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
n_list = [11,22,33,44,55,66]
print(n_list)

del n_list[3]
print(n_list)
# Out:
# [11, 22, 33, 44, 55, 66]
# [11, 22, 33, 55, 66]

# %%
a_list =[10,20,30,40,50,60,70,80]
a_list[1:5]
# Out:
# [20, 30, 40, 50]

# %%
a_list[0:5]
# Out:
# [10, 20, 30, 40, 50]

# %%
a_list[1:]
# Out:
# [20, 30, 40, 50, 60, 70, 80]

# %%
a_list[:5]
# Out:
# [10, 20, 30, 40, 50]

# %%
for n in a_list:
    print(n, end='')
# Out:
# 1020304050607080

# %%
for n in a_list:
    print(n, end=' ')
# Out:
# 10 20 30 40 50 60 70 80

# %%
 10 not in a_list
# Out:
# False

# %%
n_list = [11,22,33,44,55,66]
if (55 in n_list):
    n_list.remove(55)
if (88 in n_list):
    n_list.remove(88)
print(n_list)
# Out:
# [11, 22, 33, 44, 66]

# %%
slist =['David',178.9,'John',173.5,'Jane',176.1]
print(slist)
slist.insert(4,"Peter")
slist.insert(5,168.1)
print(slist)
# Out:
# ['David', 178.9, 'John', 173.5, 'Jane', 176.1]
# ['David', 178.9, 'John', 173.5, 'Peter', 168.1, 'Jane', 176.1]

# %%
person ={'Name':'Viraj','age': '34', 'weight':82}
del person['age']
person
# Out:
# {'Name': 'Viraj', 'weight': 82}

# %%
d1 ={'Name':'David Doe','Age':26}
d2 ={'Age':26,'Name':'David Doe'}
d1 ==d2
d1!=d2
# Out:
# False

# %%
import json

data='{"Name":"Advid Doe ","age":25,"hobby":["basketball"],"family":{"father":"John Doe","mother":"Marry Doe"},"Married":true}'

json_data = json.loads(data)

print(type(json_data))
print(json_data['Name'])
print(json_data['family'])
print(json_data['Married'])
# Out:
# <class 'dict'>
# Advid Doe
# {'father': 'John Doe', 'mother': 'Marry Doe'}
# True
