# %%
# Constructor overriding
class Parent:
    def __init__(self):
        print("Parent constructor")
class Child(Parent):
    def __init__(self):
        super().__init__()
        print("Child constructor")
c=Child()
# Out:
# Parent constructor
# Child constructor

# %%
class Parent:
    def __init__(self):
        print("Parent constructor")
    def display(self):
        print("Parent display method")
class Child(Parent):
    def __init__(self):
        super().__init__()
        print("Child constructor")
c=Child()
# Out:
# Parent constructor
# Child constructor

# %%
# Abstraction method
def add():
    a=int(input("Enter a number"))
    b=int(input("Enter a number"))
    c=a+b
    print(c)
add()

def sub():
    a=int(input("Enter a number"))
    b=int(input("Enter a number"))
    c=a-b
    print(c)
sub()
# Out:
# Enter a number 23
# Enter a number 32
# 55
# Enter a number 34
# Enter a number 32
# 2

# %%
# Password strength checker
password=input("Enter password:")
if len(password)>=8 and any(c.isdigit() for c in password):
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Enter password: dfrfgrefb343c
# Strong Password

# %%
# Password with first letter capital
password = input("Enter password:")
starts_with_capital = password[0].isupper()
if len(password) >= 8 and any(c.isdigit() for c in password) and starts_with_capital:
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Enter password: Adfndfsc23
# Strong Password

# %%
# Contact search in phone book using Dictionary
contact={"Viraj":"1234567890","Amit": "3245678901"}
name = input("Enter name:")
if name in contact:
    print("Contact number:",contact[name])
else:
    print("Contact not foung")
# Out:
# Enter name: Viraj
# Contact number: 1234567890

# %%
# fizzBuzz
def fizzBuzz(n):
    result =[]
    for i in range (1,n+1):
        if i % 3 ==0 and i % 5 == 0:
            result.append("FizzBuzz")
        elif i%3 == 0:
            result.append("Fizz")
        elif i%5 == 0:
            result.append("Buzz")
        else:
            result.append(str(i))
    return result
print(fizzBuzz(20))
# Out:
# ['1', '2', 'Fizz', '4', 'Buzz', 'Fizz', '7', '8', 'Fizz', 'Buzz', '11', 'Fizz', '13', '14', 'FizzBuzz', '16', '17', 'Fizz', '19', 'Buzz']

# %%
# File handling
# with open("file1234.txt","r") as f:
#     content

# %%
# writing to a file(overwrites existing)
with open("file1234.txt","a") as f:
    f.write("Pimpri chinchwad university ") # write in a file(need a file)
    
with open("file1234.txt","r") as f:
    content=f.read()
    print(content)
# Out:
# Pimpri chinchwad universityPimpri chinchwad universityPimpri chinchwad universityPimpri chinchwad universityPimpri chinchwad university

# %%
# file handling using append

# %%
# Read line-by-line 
with open("file1234.txt","r") as f:
    for line in f:
        print(line)
        print(line.strip()) #strip() removes newline
# Out:
# Pimpri chinchwad universityPimpri chinchwad universityPimpri chinchwad universityPimpri chinchwad universityPimpri chinchwad university
# Pimpri chinchwad universityPimpri chinchwad universityPimpri chinchwad universityPimpri chinchwad universityPimpri chinchwad university

# %%
# file existence and deletion (using os)
import os
if os.path.exists("file12.txt"):
    os.remove("file12.txt")
    print("file12.txt")
    print("File Deleted")
else:
    print("File does not exist")
# Out:
# File does not exist

# %%
# Count the words in a file
with open ("file1234.txt","r") as f:
    content = f.read()
    words=content.split()
    print("Total words:", len(words))
# Out:
# Total words: 11

# %%
# DSA
# stack
class stack:
    def __init__(self):
        self.value=[]
    def push(self,x):
        self.value=[x]+self.value
    def pop(self):
        return self.value.pop(0)
s=stack()
s.push(10)
s.push(20)
s.push(30)
print(s.value)
# Out:
# [30, 20, 10]

# %%
# using list of queue
class queue:
    def __init__(self):
        self.value=[]
    def en(self,x):
        self.value.append(x)
    def deque(self):
        front=self.value[0]
        self.value=self.value[1:]
        return front
q1=queue()
q1.en(10)
q1.en(20)
q1.en(30)
print(q1.value)
q1.deque()
# Out:
# [10, 20, 30]
# 10
